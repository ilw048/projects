# %% [markdown]
# # Прогнозирование потребления электроэнергии в городе

# %% [markdown]
# В наличии были реальные данные потребляемой мощности в городе Выборг за 2018 год, значения фиксировались каждые полчаса и датасет состоял из 19000 строк. Известно, что потребляемая мощность хорошо коррелирует с метеорологическими и сезонными факторами, поэтому предварительно был догружен архив погоды за 2018 год и добавлен к датасету. <br>
#
# Прошу учесть, что **это сырой проект**, в нем могут быть ошибки. Все предварительные исследования о влиянии различных факторов на потребляемую мощность и подбор оптимального периода предыстории для тренировочной выборки были проведены еще в 2021 году в моем дипломном проекте. Поэтому используются уже готовые эвристики. <br>
#
# Здесь я просто пробую различные методы, которые дают хороший результат на нестационарных промежутках года (осенью, зимой, весной) — самые сложные периоды для прогнозирования, которые мне раньше не поддавались.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
from keras.models import Sequential
from keras.layers import LSTM, GRU, SimpleRNN
from keras.layers import Activation, Dense
from keras.callbacks import EarlyStopping

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    mean_absolute_percentage_error as mape, 
    r2_score as r2,
    mean_absolute_error as mae, 
    mean_squared_error as mse
)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 200)

# %%
plt.rc('lines', linewidth=1)
plt.rcParams.update({'font.size': 7})

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Для прогнозов нужно вытащить максимум информации из двух столбцов: дата и потребляемая мощность. Поскольку процесс носит цикличный характер и менятся в течение суток, недели и года, были созданы соответствующие фичи.
# Также хороший прирост в точности дала разница температуры за час (2 наблюдения) — `T_diff`.

# %%
def edit(data):
    data = data.drop([5016, 5715, 5476, 5478, 1170, 1171, 1172], axis=0) #выбросы
    data.index = data['date']
    
    data = data[pd.DatetimeIndex(data.index).year == 2018] #за 2019 год мало наблюдений
    #data['season'] = data['season'].astype('category')
    #data['hours'] = pd.DatetimeIndex(data.index).hour + (pd.DatetimeIndex(data.index).minute / 60)
    data['days'] = pd.DatetimeIndex(data.index).weekday
    data['weekend'] = pd.DatetimeIndex(data.index).weekday.isin([5,6])*1
    #data['month'] = pd.DatetimeIndex(data.index).month
    data['weekofyear'] = data.index.isocalendar().week
    #data['dayofyear'] = data.index.isocalendar().day
    
    data['T_diff'] = data['T'] - data['T'].shift(2)
    
    data.drop(['time_num', 'date'], axis=1, inplace=True)
    data = data[data['P'] > 400] #исключим выбросы

    #data = pd.get_dummies(data, columns=['season'])
    return data

# %%
def code_mean(data, category_feature, real_feature):
    """
    Возвращает словарь, где ключами являются уникальные категории признака category_feature,
    а значениями - средние по real_feature
    """
    return dict(data.groupby(category_feature)[real_feature].mean())

# %%
def prepareData(data, lag_start=48, lag_end=48*7, test_size=0.2): #48 наблюдений в одних сутках на 7 дней недели
    data['P'] = data['P'] / 100 #масштабируем
    data['P_diff'] = data['P'] - data['P'].shift(1)
    test_index = int(len(data)*(1-test_size))
        
    data['week_mean'] = list(map(code_mean(data[:test_index], 'weekofyear', 'P').get, data.weekofyear))
    data['hours'] = pd.DatetimeIndex(data.index).hour + (pd.DatetimeIndex(data.index).minute / 60) #час + 0,5часа(30 минут)
    data['lag_week'] = data['week_mean'].shift(lag_end) #лаг недели
    data['timestamp'] = data.index
    
    data['moving_average'] = data['P'].rolling( #очень поможет в прогнозах
        window=48,       # 1-day window
        center=True,     # puts the average at the center of the window
        min_periods=24,  # choose about half the window size
    ).mean()             # compute the mean (could also do median, std, min, max, ...)
    
    data = data.reset_index(drop=True)
    
    columns = ['P', 'hours', 'days', 'T', 'weekend', 'lag_week', 'moving_average', 'T_diff', 'timestamp']
    x_train, x_test, y_train, y_test = train_test_split(data[columns].drop(['P'], axis=1), 
                                                        data['P'], test_size=0.2, 
                                                        random_state=42, shuffle=False).copy() #обязательно shuffle=False
    for item in [x_train, x_test, y_train, y_test]:
        item.reset_index(drop=True, inplace=True)
    
    #print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
    return x_train, y_train, x_test, y_test

# %%
def scores(y_true, y_pred):
    print('MAPE =', format(mape(y_true, y_pred) * 100, '.2f'))
    print('r2 =', format(r2(y_true, y_pred), '.3f'))
    print('MAE =', format(mae(y_true, y_pred), '.3f'))
    print('MSE =', format(mse(y_true, y_pred), '.3f'))
    print('RMSE = ', format(np.sqrt(mse(y_true, y_pred)), '.3f'))
    return None

# %%
dataset = pd.read_excel('datasets/power.xlsx', sheet_name=0)
dataset = edit(dataset)

# %%
dataset.head()
# Out:
#                           P  hours  days         T      Po    Pa          U  \
# date
# 2018-01-01 00:00:00  1209.6    3.0     0 -0.400000  752.50 -1.20  87.000000
# 2018-01-01 00:30:00  1200.8    3.5     0 -0.433333  752.25 -1.25  87.166667
# 2018-01-01 01:00:00  1191.6    4.0     0 -0.466667  752.00 -1.30  87.333333
# 2018-01-01 01:30:00  1188.4    4.5     0 -0.500000  751.75 -1.35  87.500000
# 2018-01-01 02:00:00  1155.6    5.0     0 -0.533333  751.50 -1.40  87.666667
#
#                      Ff   N     H    VV   Td  season  weekend  weekofyear  \
# date
# 2018-01-01 00:00:00   4  90  3000  10.0 -2.4  winter        0           1
# 2018-01-01 00:30:00   4  90  3000  10.0 -2.4  winter        0           1
# 2018-01-01 01:00:00   4  90  3000  10.0 -2.4  winter        0           1
# 2018-01-01 01:30:00   4  90  3000  10.0 -2.4  winter        0           1
# 2018-01-01 02:00:00   4  90  3000  10.0 -2.4  winter        0           1
#
#                        T_diff
# date
# 2018-01-01 00:00:00       NaN
# 2018-01-01 00:30:00       NaN
# 2018-01-01 01:00:00 -0.066667
# 2018-01-01 01:30:00 -0.066667
# 2018-01-01 02:00:00 -0.066667

# %% [markdown]
# ### Годовой график потребляемой мощности

# %%
plt.plot(dataset['P'])

# %% [markdown]
# Как видим, ряд нестационарный: от зимы к лету мощность постепенно снижается, к зиме — повышается. Летом ряд примерно постоянный, и поэтому там получаются самые точные прогнозы (mape 4-5%). Задача будет состоять в недельном прогнозировании по истории в 5 недель. Были выделены соответствующие сезонные периоды, чтобы проверять адекватность методов на всех сезонах года.

# %%
winter = np.arange(300,3500)
spring = np.arange(3000,6500)
summer = np.arange(6000,9500)
autumn = np.arange(9500,13000)

# %%
data = dataset.iloc[autumn].copy()

# %%
x_train, y_train, x_test, y_test = prepareData(data)

# %%
n_week = 48*7
x_train, y_train = x_train[-5*n_week:], y_train[-5*n_week:] #5 недель в трейн
x_test, y_test = x_test[:n_week], y_test[:n_week] #1 неделя в тест

for item in [x_train, x_test, y_train, y_test]:
        item.reset_index(drop=True, inplace=True)

# %%
x_test.isna().sum()
# Out:
# hours             0
# days              0
# T                 0
# weekend           0
# lag_week          0
# moving_average    0
# T_diff            0
# timestamp         0
# dtype: int64

# %% [markdown]
# Раннее было замечено, что наличие скользящего среднего очень сильно повышает гибкость методов, поскольку не все они могут аппроксимировать значения за пределы обучающей выборки, а это неизбежно ввиду нестационарности ряда. <br>
#
# Идея заключается в следующем: спрогнозируем в тестовую выборку скользящее среднее и будем использовать как фичу в окончательных прогнозах. <br>
# **Тут возникает проблема в ограниченности данных для такого прогноза: мы не можем использовать лаги по дням, среднее дня и т.п. — данные из будущего. Доступен только лаг на неделю и вариации температурных показателей.**

# %%
#для окончательного прогноза
x_train = x_train.loc[:,['hours', 'days', 'weekend', 'T', 'lag_week', 'moving_average', 'T_diff', 'timestamp']]
x_test = x_test.loc[:,['hours', 'days', 'weekend', 'T', 'lag_week', 'moving_average', 'T_diff', 'timestamp']]

# %%
x_train.head()
# Out:
#    hours  days  weekend          T  lag_week  moving_average    T_diff  \
# 0    5.5     6        1  16.550000  6.581685        6.817583  0.100000
# 1    6.0     6        1  16.600000  6.581685        6.840500  0.100000
# 2    6.5     6        1  17.016667  6.581685        6.858250  0.466667
# 3    7.0     6        1  17.433333  6.581685        6.867333  0.833333
# 4    7.5     6        1  17.850000  6.581685        6.872083  0.833333
#
#             timestamp
# 0 2018-08-12 05:30:00
# 1 2018-08-12 06:00:00
# 2 2018-08-12 06:30:00
# 3 2018-08-12 07:00:00
# 4 2018-08-12 07:30:00

# %%
#для скользящего среднего
moving_features = ['hours', 'days', 'weekend', 'T', 'lag_week', 'T_diff']

# %%
x_train_moving = x_train.loc[:, moving_features]
x_test_moving = x_test.loc[:, moving_features]

# %%
y_train_moving = y_train
y_test_moving = y_test

# %%
x_train_moving, x_val_moving, y_train_moving, y_val_moving = train_test_split(x_train_moving, y_train_moving, test_size=0.2, 
                                                                      random_state=42, shuffle=False).copy()

# %% [markdown]
# ## Прогнозирование скользящего среднего

# %% [markdown]
# По сути это было самой сложной задачей: по минимуму доступных данных хотя бы грубо научиться предсказывать тренд. Случайный лес и градиентный бустинг не подошли, потому что деревья не аппроксимируют зависимость. Более-менее нормальные прогнозы дала *рекурентная нейронная сеть с долгой краткосрочной памятью LSTM*, но не во всех сезонах она работала хорошо. Поэтому также была добавлена *линейная регрессия Надарая Ватсона*, которая заменяла нейронную сеть в случае плохих результатов. <br>
#
# Выбор наилучшей модели проводился на заранее отложенной валидационной выборке.

# %% [markdown]
# ### LSTM

# %%
rnn = Sequential()
rnn.add(LSTM(units=30, input_shape=[x_train_moving.shape[1], 1], activation='relu'))
rnn.add(Dense(30, activation='relu'))
rnn.add(Dense(1))

opt = keras.optimizers.Adam(learning_rate=0.005)
rnn.compile(loss='mse', optimizer=opt)#, metrics=[last_time_step_mse])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.01)

# %%
rnn.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 30)                3840
#
#  dense_12 (Dense)            (None, 30)                930
#
#  dense_13 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 4,801
# Trainable params: 4,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
def fit_moving():
    for i in range(1,6):
        rnn.fit(x_train_moving, y_train_moving, epochs=30, batch_size=24, validation_split=0.2, callbacks=[early_stopping])
    pred = pd.Series(rnn.predict(x_val_moving).ravel())
    return pred

# %% [markdown]
# Тут спорный момент, но несколько итераций с меньшим числом эпох давало результаты лучше, иначе `early_stop` не позволял дообучить модель.

# %%
best_pred_moving = fit_moving()
# Out:
# Epoch 1/30
# 45/45 [==============================] - 2s 13ms/step - loss: 6.0850 - val_loss: 3.2197
# Epoch 2/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6549 - val_loss: 2.3210
# Epoch 3/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6091 - val_loss: 2.7809
# Epoch 4/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.5831 - val_loss: 2.3103
# Epoch 5/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.5956 - val_loss: 2.4724
# Epoch 6/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.5672 - val_loss: 2.9545
# Epoch 7/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.5951 - val_loss: 2.6720
# Epoch 8/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.5681 - val_loss: 2.2856
# Epoch 9/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.5076 - val_loss: 2.5037
# Epoch 10/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4688 - val_loss: 2.6557
# Epoch 11/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4876 - val_loss: 2.3884
# Epoch 12/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4698 - val_loss: 2.4802
# Epoch 13/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4458 - val_loss: 2.6124
# Epoch 1/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.4641 - val_loss: 2.2736
# Epoch 2/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4877 - val_loss: 2.5009
# Epoch 3/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4392 - val_loss: 2.4894
# Epoch 4/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4809 - val_loss: 3.0248
# Epoch 5/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4742 - val_loss: 2.3358
# Epoch 6/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4473 - val_loss: 2.6408
# Epoch 1/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.4136 - val_loss: 2.2776
# Epoch 2/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4487 - val_loss: 2.5769
# Epoch 3/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4621 - val_loss: 2.1862
# Epoch 4/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4421 - val_loss: 2.6134
# Epoch 5/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4612 - val_loss: 2.1823
# Epoch 6/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.3594 - val_loss: 2.1697
# Epoch 7/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.3474 - val_loss: 2.2552
# Epoch 8/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.3090 - val_loss: 2.4680
# Epoch 9/30
# 45/45 [==============================] - 0s 6ms/step - loss: 0.3664 - val_loss: 2.4018
# Epoch 10/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2679 - val_loss: 2.0938
# Epoch 11/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2720 - val_loss: 2.2742
# Epoch 12/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2462 - val_loss: 2.2817
# Epoch 13/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2555 - val_loss: 2.7357
# Epoch 14/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2525 - val_loss: 2.2149
# Epoch 15/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2270 - val_loss: 2.0424
# Epoch 16/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.2613 - val_loss: 2.1690
# Epoch 17/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2082 - val_loss: 2.1518
# Epoch 18/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2283 - val_loss: 2.1295
# Epoch 19/30
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2066 - val_loss: 2.2404
# Epoch 20/30
# 45/45 [==============================] - 1s 17ms/step - loss: 0.2381 - val_loss: 2.0577
# Epoch 1/30
# 45/45 [==============================] - 1s 11ms/step - loss: 0.2217 - val_loss: 1.9819
# Epoch 2/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2466 - val_loss: 2.1357
# Epoch 3/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.2078 - val_loss: 2.1055
# Epoch 4/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2073 - val_loss: 2.1103
# Epoch 5/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2093 - val_loss: 2.2025
# Epoch 6/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1862 - val_loss: 2.1726
# Epoch 1/30
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1773 - val_loss: 2.1164
# Epoch 2/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1902 - val_loss: 2.2914
# Epoch 3/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1861 - val_loss: 2.1001
# Epoch 4/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.1888 - val_loss: 2.1579
# Epoch 5/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1832 - val_loss: 2.1030
# Epoch 6/30
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1923 - val_loss: 2.0559
# Epoch 7/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.1722 - val_loss: 2.5213
# Epoch 8/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.1929 - val_loss: 2.4800
# Epoch 9/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.2010 - val_loss: 2.0549
# Epoch 10/30
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1847 - val_loss: 2.0533
# Epoch 11/30
# 45/45 [==============================] - 0s 9ms/step - loss: 0.1943 - val_loss: 2.0899

# %%
plt.figure(figsize=(5,2.5))
plt.plot(best_pred_moving.rolling(
        window=48,       # 1-day window
        center=True,     # puts the average at the center of the window
        min_periods=6  # choose about half the window size
        ).mean(), label='pred')
plt.plot(pd.Series(y_val_moving.values).rolling(
        window=48,       # 1-day window
        center=True,     # puts the average at the center of the window
        min_periods=6  # choose about half the window size
        ).mean(), label='test')
plt.legend(loc='best')
plt.title(f'LSTM trend & y_val\n Mean absolute percentage error: {mape(y_val_moving, best_pred_moving):.2%}')
plt.grid(True)

# %%
#plt.rcParams['font.size'] = '7'
plt.figure(figsize=(5,2.5))
plt.plot(best_pred_moving, label='pred')
plt.plot(pd.Series(y_val_moving.values), label='test')
plt.legend(loc='best')
plt.title(f'LSTM trend & y_val\n Mean absolute percentage error: {mape(y_val_moving, best_pred_moving):.2%}')
plt.grid(True)

# %% [markdown]
# По сути мы уже получили готовые прогнозы для мощности, иногда они уже бывают приемлемыми, но так выходит не всегда. Если же воспользоваться ими и дообучить модели, как правило, получаются более точные результаты.

# %%
scores(y_val_moving, best_pred_moving)
# Out:
# MAPE = 4.68
# r2 = 0.750
# MAE = 0.381
# MSE = 0.216
# RMSE =  0.465

# %% [markdown]
# ### Линейная модель: регрессия Надарая-Ватсона

# %%
from sklearn.kernel_ridge import KernelRidge
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit, KFold

tscv = TimeSeriesSplit(n_splits=3)
kf = KFold(n_splits=3, shuffle=False)
krr = KernelRidge()

param_grid = {'alpha': [10, 100, 200, 500], 'degree': list(range(2,4)), 'kernel': ['polynomial', 'linear']}
grid = GridSearchCV(krr, param_grid=param_grid, cv=kf, verbose=3, scoring='neg_mean_squared_error')

# %%
grid.fit(x_train_moving, y_train_moving)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV 1/3] END alpha=10, degree=2, kernel=polynomial;, score=-0.675 total time=   0.0s
# [CV 2/3] END alpha=10, degree=2, kernel=polynomial;, score=-0.699 total time=   0.0s
# [CV 3/3] END alpha=10, degree=2, kernel=polynomial;, score=-1.528 total time=   0.0s
# [CV 1/3] END alpha=10, degree=2, kernel=linear;, score=-0.680 total time=   0.0s
# [CV 2/3] END alpha=10, degree=2, kernel=linear;, score=-0.790 total time=   0.0s
# [CV 3/3] END alpha=10, degree=2, kernel=linear;, score=-1.646 total time=   0.0s
# [CV 1/3] END alpha=10, degree=3, kernel=polynomial;, score=-1.570 total time=   0.1s
# [CV 2/3] END alpha=10, degree=3, kernel=polynomial;, score=-0.805 total time=   0.1s
# [CV 3/3] END alpha=10, degree=3, kernel=polynomial;, score=-3.780 total time=   0.1s
# [CV 1/3] END alpha=10, degree=3, kernel=linear;, score=-0.680 total time=   0.0s
# [CV 2/3] END alpha=10, degree=3, kernel=linear;, score=-0.790 total time=   0.0s
# [CV 3/3] END alpha=10, degree=3, kernel=linear;, score=-1.646 total time=   0.0s
# [CV 1/3] END alpha=100, degree=2, kernel=polynomial;, score=-0.499 total time=   0.0s
# [CV 2/3] END alpha=100, degree=2, kernel=polynomial;, score=-0.707 total time=   0.0s
# [CV 3/3] END alpha=100, degree=2, kernel=polynomial;, score=-1.624 total time=   0.0s
# [CV 1/3] END alpha=100, degree=2, kernel=linear;, score=-0.729 total time=   0.0s
# [CV 2/3] END alpha=100, degree=2, kernel=linear;, score=-0.767 total time=   0.0s
# [CV 3/3] END alpha=100, degree=2, kernel=linear;, score=-1.634 total time=   0.0s
# [CV 1/3] END alpha=100, degree=3, kernel=polynomial;, score=-1.068 total time=   0.1s
# [CV 2/3] END alpha=100, degree=3, kernel=polynomial;, score=-0.698 total time=   0.1s
# [CV 3/3] END alpha=100, degree=3, kernel=polynomial;, score=-2.388 total time=   0.1s
# [CV 1/3] END alpha=100, degree=3, kernel=linear;, score=-0.729 total time=   0.0s
# [CV 2/3] END alpha=100, degree=3, kernel=linear;, score=-0.767 total time=   0.0s
# [CV 3/3] END alpha=100, degree=3, kernel=linear;, score=-1.634 total time=   0.0s
# [CV 1/3] END alpha=200, degree=2, kernel=polynomial;, score=-0.429 total time=   0.0s
# [CV 2/3] END alpha=200, degree=2, kernel=polynomial;, score=-0.751 total time=   0.0s
# [CV 3/3] END alpha=200, degree=2, kernel=polynomial;, score=-1.757 total time=   0.0s
# [CV 1/3] END alpha=200, degree=2, kernel=linear;, score=-0.786 total time=   0.0s
# [CV 2/3] END alpha=200, degree=2, kernel=linear;, score=-0.753 total time=   0.0s
# [CV 3/3] END alpha=200, degree=2, kernel=linear;, score=-1.651 total time=   0.0s
# [CV 1/3] END alpha=200, degree=3, kernel=polynomial;, score=-0.941 total time=   0.1s
# [CV 2/3] END alpha=200, degree=3, kernel=polynomial;, score=-0.684 total time=   0.1s
# [CV 3/3] END alpha=200, degree=3, kernel=polynomial;, score=-2.058 total time=   0.1s
# [CV 1/3] END alpha=200, degree=3, kernel=linear;, score=-0.786 total time=   0.0s
# [CV 2/3] END alpha=200, degree=3, kernel=linear;, score=-0.753 total time=   0.0s
# [CV 3/3] END alpha=200, degree=3, kernel=linear;, score=-1.651 total time=   0.0s
# [CV 1/3] END alpha=500, degree=2, kernel=polynomial;, score=-0.396 total time=   0.0s
# [CV 2/3] END alpha=500, degree=2, kernel=polynomial;, score=-0.838 total time=   0.0s
# [CV 3/3] END alpha=500, degree=2, kernel=polynomial;, score=-1.958 total time=   0.0s
# [CV 1/3] END alpha=500, degree=2, kernel=linear;, score=-0.949 total time=   0.0s
# [CV 2/3] END alpha=500, degree=2, kernel=linear;, score=-0.754 total time=   0.0s
# [CV 3/3] END alpha=500, degree=2, kernel=linear;, score=-1.745 total time=   0.0s
# [CV 1/3] END alpha=500, degree=3, kernel=polynomial;, score=-0.774 total time=   0.1s
# [CV 2/3] END alpha=500, degree=3, kernel=polynomial;, score=-0.673 total time=   0.1s
# [CV 3/3] END alpha=500, degree=3, kernel=polynomial;, score=-1.754 total time=   0.1s
# [CV 1/3] END alpha=500, degree=3, kernel=linear;, score=-0.949 total time=   0.0s
# [CV 2/3] END alpha=500, degree=3, kernel=linear;, score=-0.754 total time=   0.0s
# [CV 3/3] END alpha=500, degree=3, kernel=linear;, score=-1.745 total time=   0.0s
# GridSearchCV(cv=KFold(n_splits=3, random_state=None, shuffle=False),
#              estimator=KernelRidge(),
#              param_grid={'alpha': [10, 100, 200, 500], 'degree': [2, 3],
#                          'kernel': ['polynomial', 'linear']},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
#print('MSE =', -grid.best_score_)
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'alpha': 100, 'degree': 2, 'kernel': 'polynomial'}
# KernelRidge(alpha=100, degree=2, kernel='polynomial')

# %%
krr = grid.best_estimator_

# %%
krr.fit(x_train_moving, y_train_moving) #обучаем на всем датасете
lr_best_pred_moving = pd.Series(krr.predict(x_val_moving))

# %%
#krr = KernelRidge(alpha=500, kernel='polynomial', degree=3)
#krr.fit(x_train_moving, y_train_moving)
#lr_best_pred_moving = pd.Series(krr.predict(x_val_moving))

# %%
scores(y_val_moving, lr_best_pred_moving)
# Out:
# MAPE = 7.54
# r2 = 0.261
# MAE = 0.634
# MSE = 0.640
# RMSE =  0.800

# %%
plt.figure(figsize=(5,2.5))
plt.plot(lr_best_pred_moving.rolling(
        window=48,       # 1-day window
        center=True,     # puts the average at the center of the window
        min_periods=6  # choose about half the window size
        ).mean(), label='pred')
plt.plot(pd.Series(y_val_moving.values).rolling(
        window=48,       # 1-day window
        center=True,     # puts the average at the center of the window
        min_periods=6  # choose about half the window size
        ).mean(), label='test')
plt.legend(loc='best')
plt.title(f'Kernel regression trend & y_val\n Mean absolute percentage error: {mape(y_val_moving, lr_best_pred_moving):.2%}')
plt.grid(True)

# %%
plt.figure(figsize=(5,2.5))
plt.plot(pd.Series(krr.predict(x_test_moving).ravel()).rolling(
        window=48,       # 1-day window
        center=True,     # puts the average at the center of the window
        min_periods=6  # choose about half the window size
        ).mean(), label='pred')
plt.plot(pd.Series(y_val_moving.values).rolling(
        window=48,       # 1-day window
        center=True,     # puts the average at the center of the window
        min_periods=6  # choose about half the window size
        ).mean(), label='test')
plt.legend(loc='best')
plt.title(f'Kernel regression trend & y_val\n Mean absolute percentage error: {mape(y_test_moving, lr_best_pred_moving):.2%}')
plt.grid(True)

# %% [markdown]
# #### Выбор модели для прогнозирования фичи `moving_average`

# %%
scores(y_val_moving, rnn.predict(x_val_moving)) #LSTM val
# Out:
# MAPE = 4.68
# r2 = 0.750
# MAE = 0.381
# MSE = 0.216
# RMSE =  0.465

# %%
scores(y_val_moving, krr.predict(x_val_moving)) #Kernel val
# Out:
# MAPE = 7.54
# r2 = 0.261
# MAE = 0.634
# MSE = 0.640
# RMSE =  0.800

# %%
def best_moving(krr, rnn):
    if r2(y_val_moving, rnn.predict(x_val_moving)) > r2(y_val_moving, krr.predict(x_val_moving)):
        return pd.Series(rnn.predict(x_test_moving).ravel())
    return pd.Series(krr.predict(x_test_moving))

# %% [markdown]
# Добавляем `'moving_average'` в тест:

# %%
x_test['moving_average'] = best_moving(krr, rnn).rolling(
    window=48, 
    center=True, 
    min_periods=6
).mean()

# %% [markdown]
# ### Окончательное прогнозирование потребляемой мощности

# %%
features = ['hours', 'days', 'weekend', 'T', 'lag_week', 'moving_average', 'T_diff']

# %%
rnn1 = Sequential()
rnn1.add(LSTM(units=30, input_shape=[x_train[features].shape[1], 1], activation='relu'))
rnn1.add(Dense(30, activation='relu'))
rnn1.add(Dense(1))

opt = keras.optimizers.Adam(learning_rate=0.005)
rnn1.compile(loss='mse', optimizer=opt)

# %%
early_stopping_p = EarlyStopping(monitor='val_loss', patience=5, min_delta=0.01)

# %%
def fit_p():
    for i in range(1,6):
        rnn1.fit(x_train[features], y_train, epochs=30, batch_size=24, validation_split=0.25, callbacks=[early_stopping_p])
        pred = rnn1.predict(x_test[features])
        print('****************R2_test = ', r2(y_test, pred))

    return pred

# %%
best_pred = fit_p()
# Out:
# Epoch 1/30
# 53/53 [==============================] - 3s 15ms/step - loss: 5.6086 - val_loss: 0.9582
# Epoch 2/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.9671 - val_loss: 1.1295
# Epoch 3/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.8469 - val_loss: 0.9798
# Epoch 4/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.7528 - val_loss: 0.6660
# Epoch 5/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.6609 - val_loss: 0.8041
# Epoch 6/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.7097 - val_loss: 0.5759
# Epoch 7/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.6721 - val_loss: 0.6987
# Epoch 8/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.5594 - val_loss: 0.6012
# Epoch 9/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.4360 - val_loss: 0.5927
# Epoch 10/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.4521 - val_loss: 0.4977
# Epoch 11/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3653 - val_loss: 0.3245
# Epoch 12/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3300 - val_loss: 0.3923
# Epoch 13/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3092 - val_loss: 0.7813
# Epoch 14/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.3640 - val_loss: 0.3880
# Epoch 15/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.3766 - val_loss: 0.4191
# Epoch 16/30
# 53/53 [==============================] - 0s 7ms/step - loss: 0.2957 - val_loss: 0.3528
# ****************R2_test =  0.5576237840988743
# Epoch 1/30
# 53/53 [==============================] - 1s 11ms/step - loss: 0.3533 - val_loss: 0.2261
# Epoch 2/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2493 - val_loss: 0.5866
# Epoch 3/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2189 - val_loss: 0.3331
# Epoch 4/30
# 53/53 [==============================] - 0s 9ms/step - loss: 0.2410 - val_loss: 0.2390
# Epoch 5/30
# 53/53 [==============================] - 0s 9ms/step - loss: 0.2265 - val_loss: 0.4191
# Epoch 6/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2158 - val_loss: 0.5225
# ****************R2_test =  0.37988426196379155
# Epoch 1/30
# 53/53 [==============================] - 1s 12ms/step - loss: 0.2363 - val_loss: 0.2322
# Epoch 2/30
# 53/53 [==============================] - 0s 9ms/step - loss: 0.2136 - val_loss: 0.2795
# Epoch 3/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2357 - val_loss: 0.5924
# Epoch 4/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1752 - val_loss: 0.3914
# Epoch 5/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1592 - val_loss: 0.3895
# Epoch 6/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1536 - val_loss: 0.3232
# ****************R2_test =  0.567949628850391
# Epoch 1/30
# 53/53 [==============================] - 1s 11ms/step - loss: 0.1722 - val_loss: 0.2347
# Epoch 2/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2168 - val_loss: 0.1853
# Epoch 3/30
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1492 - val_loss: 0.2822
# Epoch 4/30
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1613 - val_loss: 0.2111
# Epoch 5/30
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1388 - val_loss: 0.2783
# Epoch 6/30
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1716 - val_loss: 0.4581
# Epoch 7/30
# 53/53 [==============================] - 1s 10ms/step - loss: 0.2338 - val_loss: 0.3543
# ****************R2_test =  0.5865959293250111
# Epoch 1/30
# 53/53 [==============================] - 1s 12ms/step - loss: 0.1715 - val_loss: 0.2104
# Epoch 2/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1838 - val_loss: 0.4411
# Epoch 3/30
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1625 - val_loss: 0.2822
# Epoch 4/30
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1457 - val_loss: 0.1493
# Epoch 5/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1579 - val_loss: 0.2038
# Epoch 6/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1686 - val_loss: 0.1570
# Epoch 7/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1751 - val_loss: 0.2906
# Epoch 8/30
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1600 - val_loss: 0.2872
# Epoch 9/30
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1391 - val_loss: 0.3121
# ****************R2_test =  0.4671239733834318

# %%
plt.figure(figsize=(6,2.5))
plt.plot(best_pred*100, label='pred',linewidth=1) #домножаем на 100, чтобы вернуть масштаб
plt.plot(y_test*100, color='orange', label='test',linewidth=1)
plt.legend(loc='best')
plt.title(f'LSTM & y_test\n Mean absolute percentage error: {mape(y_test, best_pred):.2%}')
plt.grid(True)

# %%
scores(y_test*100, best_pred*100)
# Out:
# MAPE = 7.18
# r2 = 0.467
# MAE = 64.385
# MSE = 6958.134
# RMSE =  83.415

# %% [markdown]
# ## Случайный лес

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, max_depth=12)
rf.fit(x_train[features], y_train)
rf_pred = rf.predict(x_test[features])

# %%
plt.figure(figsize=(6,2.5))
plt.plot(rf_pred*100, label='pred')
plt.plot(y_test.values*100, color='orange', label='y_test')
plt.legend(loc='best')
plt.title(f'Random Forest & y_test\n Mean absolute percentage error: {mape(y_test, rf_pred):.2%}')
plt.grid(True)

# %%
scores(y_test*100, rf_pred*100)
# Out:
# MAPE = 6.25
# r2 = 0.559
# MAE = 56.546
# MSE = 5764.081
# RMSE =  75.922

# %% [markdown]
# ## Градиентный бустинг

# %%
from catboost import CatBoostRegressor

#features = ['hours', 'days', 'weekend', 'T', 'lag_week', 'moving_average', 'T_diff']    

cat = CatBoostRegressor(iterations=500, learning_rate=0.07, loss_function='RMSE')
cat.fit(x_train[features], y_train, cat_features=['days', 'weekend'], verbose=False, plot=False)
cat_pred = cat.predict(x_test[features])

# %%
plt.figure(figsize=(6,2.5))
plt.plot(cat_pred*100, label='pred')
plt.plot(y_test.values*100, color='orange', label='y_test')
plt.legend(loc='best')
plt.title(f'CatBoost & y_test\n Mean absolute percentage error: {mape(y_test, cat_pred):.2%}')
plt.grid(True)

# %%
scores(y_test*100, cat_pred*100)
# Out:
# MAPE = 6.12
# r2 = 0.562
# MAE = 55.400
# MSE = 5723.563
# RMSE =  75.654

# %% [markdown]
# В конечном счете, как правило, именно градиентный бустинг показывает наилучший результат: вне зависимости от выбора между kernel и LSTM при прогнозировании `moving_average`.
